# %%
a=input()
type(a)
# Out:
#  Ramakant
# str

# %%
b=input
# Out:
# enter your age : 20
# '20'

# %%
s=input("enter your age :")
print("entered value is :",s)
print ("entered value type is:",type(s))
# Out:
# enter your age : 20
# entered value is : 20
# entered value type is: <class 'str'>

# %%
d=int(input("enter your age :"))
print("the entered value is:",d)
print("data type of entered value :",type(d))
# Out:
# enter your age : 20
# the entered value is: 20
# data type of entered value : <class 'int'>

# %%
k=float(input("enter your age :"))
print("entered the value is:",k)
print("value type is :",type(k))
# Out:
# enter your age : 23
# entered the value is: 23.0
# value type is : <class 'float'>

# %%
name=input("whart is your name :")
age=int(input ("enter your age :"))
print("It was nice talking you",name,"!")
print("hey,you are slready",age,"years old",name,"!")
# Out:
# whart is your name : rk
# enter your age : 20
# It was nice talking you rk !
# hey,you are slready 20 years old rk !

# %% [markdown]
# VARIABLE

# %%
a=10
print(a)
print(type(a))
# Out:
# 10
# <class 'int'>

# %%
_a=10
print(_a)
print(type(_a))
type(a)
# Out:
# 10
# <class 'int'>
# int

# %% [markdown]
# RESERVE WORDS CAN'T USED AS A VARIABLE

# %%
if=10
if
# Out:
#   Cell In[22], line 1
#     if=10
#       ^
# SyntaxError: invalid syntax

# %%
else=38
print(else)
# Out:
#   Cell In[24], line 1
#     else=38
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ** SINGLE VARIABLE STORE MULTIPLE VALUES AS A TUPLE

# %%
A=10,20,30
print(A)
# Out:
# (10, 20, 30)

# %% [markdown]
# MULTIPLE VARIABLE ASSIGNMENT

# %%
a,b=10,20
print(a,b)
# Out:
# 10 20

# %%
a,b=10,20
print(b)
# Out:
# 20

# %%
a,b,n=10,20
print(a,b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 a,b,n=10,20
#       2 print(a,b)
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
a,b=10,20,30
print(a,b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 a,b=10,20,30
#       2 print(a,b)
#
# ValueError: too many values to unpack (expected 2)

# %%
a,b=10,(20,30)
print("a=",a,"b=",b)
# Out:
# a= 10 b= (20, 30)

# %%
l=a=(20,30)
print(l)
# Out:
# (20, 30)

# %% [markdown]
# # PRINT

# %% [markdown]
# ## PRINT SINGLE VALUE

# %%
print("rk")
# Out:
# rk

# %%
print(5.3)
# Out:
# 5.3

# %%
print("Ramakant",20,"b.tech","Bhopal")
# Out:
# Ramakant 20 b.tech Bhopal

# %%
print("Ramakant",20,"b.tech","Bhopal",sep=" =/% ")
# Out:
# Ramakant =/% 20 =/% b.tech =/% Bhopal

# %%
print(4.5.3.3)
# Out:
#   Cell In[104], line 1
#     print(4.5.3.3)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# ##PRINT MULTIPLE VALUE

# %%
print(10 ,20,30,40)
# Out:
# 10 20 30 40

# %%
print(10 ,20,30,40,sep=",")
# Out:
# 10,20,30,40

# %%
print(10 ,20,30,40,sep=" & ")
# Out:
# 10 & 20 & 30 & 40

# %%
a,b=20 ,30;
print("the value of a:",a,"the value of b:",b)
# Out:
# the value of a: 20 the value of b: 30

# %% [raw]
# #ohter

# %% [raw]
# .FORMAT

# %%
name ='RAMAKANT'
age=20
print("my name is :",name)
# Out:
# my name is : RAMAKANT

# %%
a=10
print("the value of a:",a)
# Out:
# the value of a: 10

# %%
a=10
print("the value of a:",{})
# Out:
# the value of a: {}

# %%
a=10
print("the value of a:{}".format(a))
# Out:
# the value of a:10

# %%
a,b=20 ,30;
print("the value of a:{} and the value of b:{}".format(a,b))
print(id(a))
id(b)
# Out:
# the value of a:20 and the value of b:30
# 140728898829336
# 140728898829656

# %% [markdown]
# TO PRINT COMBINATION OF VALUES & VARIAVLES

# %%
name ='RAMAKANT'
AGE=20
print("my name is :",name ,"and","my age is :",AGE)
# Out:
# my name is : RAMAKANT and my age is : 20

# %% [markdown]
# # task questions

# %%
x=10
print(x)
# Out:
# 10

# %%
a,b=(5,15)
print(a,b)
# Out:
# 5 15

# %%
a=15
b=a
print(a,b)
# Out:
# 15 15

# %%
# SWAP THE VALUE OF VARIABLES P AND QIF P=8 AND Q=12,THEN PRINT THEM
a,b=(8,12)
a,b=b,a
print(a,b)


temp=p=8
p=q=12
q=temp
print(p,q)
# Out:
# 12 8
# 12 8

# %%
#ASSIGN THE VALUE 5,10AND 15 OF THE VARIABLE A,B AND C RESPECTIVELY ,AND PRINT THEM

A,B,C=(5,6,7)
print(A,B,C)
# Out:
# 5 6 7

# %%
# assign the value 20 to three variable x,y and z,then print them
x=y=z=20
print(x,y,z)
# Out:
# 20 20 20

# %%
# ASSIGN THE VALUE OF 20 TO A VARIABLE Y AND PRINT ITS VALUE AND ADDRESS 

Y=20
print(y)
id(y)
# Out:
# 20
# 140721033788440

# %%
#assign the value 30 to a variable z,print it and then delete the variable 

z=30
print(z)
del z
# Out:
# 30

# %%
del z
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 del z
#
# NameError: name 'z' is not defined

# %%
# ASSIGN THE VALUE 7 AND 14 TO A VARIABLE M AND N ,PRINT THEM AND THEN DELETE BOTH VARIABLE 

A,B=7,8
print(A,B)
# Out:
# 7 8

# %%
del A,B

# %%
 # ASSIGN VALUE 1,2,3 TO X,Y,Z RESPECTIVELY,THEN DELETE Y AND PRINT X AND Z
x,y,z=1,2,3
del y
print(x,z)
# Out:
# 1 3

# %%
#ASSIGN 50 TO A AND PRINT ITS MEMORY ADDRESS
A=50
id(A)
# Out:
# 140721033789400

# %%
#ASSIGN THE VALUE 50 TO A VARIABLE P AND Q ,PRINT  THEIR VALUE AND ADDRESSES

P=Q=50 
print(P,Q)
print(id(P))
id (Q)
# Out:
# 50 50
# 140721033789400
# 140721033789400

# %%
# ASSIGN THE STRING "HELLO" TO A VARIABLE GREETING AND PRINT THEM

greeting= 'hello'
print(greeting)
# Out:
# hello

# %%
# ASSIGN THE STRING "HELLO" TO A VARIABLE GREETING AND PRINT ITS MEMORY ADDRESS

greeting= 'hello'
id(greeting)
# Out:
# 2593486125504

# %%
# assign complex (1,2) to c and print its memoty address
c=1+2j
print(c)
id (c)
# Out:
# (1+2j)
# 2593562089808

# %%
# assign the value 100 to a variable a, print its address then change its value to 200 and print its new value 

a=100
print(id(a))
a=200
id (a)
# Out:
# 140721033791000
# 140721033794200

# %%
# assign the value true to variable flag and print it

flag=True
print (flag)
# Out:
# True

# %% [markdown]
# **ASSIGN TH VALUE 10 TO AVARIABLE NAMED X AND PRINT IT**

# %% [markdown]
# X=10
# print(X)

# %% [markdown]
# **ASSIGN THE VALUE 5 AND 15 TO AVARIABLE NAMED X AND Y RESPECTIVELY AND PRINT IT**

# %%
x,y=5,15
x,y
# Out:
# (5, 15)

# %% [markdown]
# **3. assign the value of a to b ,where a=15,and then print both vavariable .**

# %%
a=15
b=a
a,b
# Out:
# (15, 15)

# %% [markdown]
# **4.swap the value of variable p and q if p=8 and q=12,then print them.**

# %%
#option 1
r=p=8
p=q=12
q=r
print(p,q)

#option 2
p,q=8,12
p,q=q,p
p,q
# Out:
# 12 8
# (12, 8)

# %% [markdown]
# **5.assign the value 5,10 and 15 to the variables a,b and c respectively, and print them.**

# %%
a,b,c=5,10,15
a,b,c
# Out:
# (5, 10, 15)

# %% [markdown]
# **6.assign the same value 20 to three variable x,y and z,then print them.**

# %%
x=y=z=20
print(x,y,z)
# Out:
# 20 20 20

# %% [markdown]
# **7..assign the same value 20 to a variable y and print its value and address.**

# %%
y=20
print(y)
id(y)
# Out:
# 20
# 140736670874648

# %% [markdown]
# **8.assign the same value 30 to a variable z,print it,and then delete the variable.**

# %%
z=30
print(z)
del z
z
# Out:
# 30
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 4
#       2 print(z)
#       3 del z
# ----> 4 z
#
# NameError: name 'z' is not defined

# %% [markdown]
# **9.aasign the value 7 and 14 to variables m and n, print them, and then delete both variables.**

# %%
m,n=7,14
print(m,n)
del (m,n)
m,n
# Out:
# 7 14
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 4
#       2 print(m,n)
#       3 del (m,n)
# ----> 4 m,n
#
# NameError: name 'm' is not defined

# %% [markdown]
# **10.assign values 1,2,3 to x,y,z,respectively,then delete y and print x and z.**

# %%
x,y,z=1,2,3
del y
print(x,z)
y
# Out:
# 1 3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 4
#       2 del y
#       3 print(x,z)
# ----> 4 y
#
# NameError: name 'y' is not defined

# %% [markdown]
# **11. assign 50 to a and print its memory address.**

# %%
a=50
id(a)
# Out:
# 140736670875608

# %% [markdown]
# **12.assign the value 50 to two variables p and q,print their values and address.**

# %%
p=q=50
print(p,q)
print(id(p))
id(q)
# Out:
# 50 50
# 140736670875608
# 140736670875608

# %% [markdown]
# **13.assign the string 'HELLO' to a variable greeting and print it .**

# %%
greeting='hello'
greeting
# Out:
# 'hello'

# %% [markdown]
# **14.assign the string 'HELLO' to a variable greeting and print its memory address.**

# %%
greeting='hello'
print(greeting)
id(greeting)
# Out:
# hello
# 2962688359376

# %% [markdown]
# **15.assign complex(1,2)to c and print its memory address.**

# %%
c=1+2j
print(c)
id(c)
# Out:
# (1+2j)
# 2962763944656

# %% [markdown]
# **16.assign the value 100 to a variable a , print its address,then change its value 200 and print its new address.**

# %%
a=100
print(a)
print(id(a))
a=200
print(a)
id(a)
# Out:
# 100
# 140736670877208
# 200
# 140736670880408

# %% [markdown]
# **17.assign the value True to a variable flag and print it.**

# %%
flag=True
flag
# Out:
# True

# %% [markdown]
# **18.assign the value 300 to a variable k,delete the variable,and then reassign it with the value 600 and print it .**

# %%
k=300
del k
k=600
k
# Out:
# 600

# %% [markdown]
# **19.assign the string "apple","banana",and "cherry" to the variables fruit1,fruit2 and fruit3 respectively and print them.**

# %%
fruit1,fruit2,fruit3='apple','banana','cherry'
print(fruit1,fruit2,fruit3)
# Out:
# apple banana cherry

# %% [markdown]
# **20.assign the floar value 9.99 to a variable price and print it.**

# %%
price=9.99
price
# Out:
# 9.99

# %% [markdown]
# **21.aggign 7.5 to b and print its memory address.**

# %%
b=7.5
print(b)
id(b)
# Out:
# 7.5
# 2962762923440

# %% [markdown]
# **22.assign the value 3.14 to pi and the value 2.718 to e,then print both variables.**

# %%
pi,e=3.14,2.718
pi,e
# Out:
# (3.14, 2.718)

# %% [markdown]
# **23.assign the values 1,2 and 3 to variables a,b and c,and print their addresses.**

# %%
a,b,c=1,2,3
print(id(a))
print(id(b))
id(c)
# Out:
# 140736670874040
# 140736670874072
# 140736670874104

# %% [markdown]
# **24.assign a string "john",an integer 25, and a boolean false to variable name, age and status,and print them.**

# %%
name,age,status="john",25,False
name,age,status
# Out:
# ('john', 25, False)

# %% [markdown]
# **25.assign the value True to both variables x and y, and print them.**

# %%
x=y=True
x,y
# Out:
# (True, True)

# %% [markdown]
# **26.assign 500 to m and 500 to n ,print their value and addresses .**

# %%
m=n=500
print(m,n)
print(id(m))
id(n)
# Out:
# 500 500
# 2962763942384
# 2962763942384

# %% [markdown]
# **27. assign 10 to x, then change it to 20,30 and finally 40, and print the final value .**

# %%
x=10
x=20
x=30
x=40
x
# Out:
# 40

# %% [markdown]
# **28.assign 1000 to x, print its address,then delete x.**

# %%
x=1000
print(x)
print(id(x))
del x
x
# Out:
# 1000
# 2962763943888
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[117], line 5
#       3 print(id(x))
#       4 del x
# ----> 5 x
#
# NameError: name 'x' is not defined

# %% [markdown]
# **29.assign the value 42,'answer',and True to variable num ,word and boolean ,print them and then delete all three variable.**

# %%
num,word,boolean=42,'answer',True
print(num,word,boolean)
del num,word,boolean
num,word,boolean
# Out:
# 42 answer True
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[130], line 4
#       2 print(num,word,boolean)
#       3 del num,word,boolean
# ----> 4 num,word,boolean
#
# NameError: name 'num' is not defined

# %% [markdown]
# **30.how do you create an integer variable with the value 25?**

# %%
a=25
print(a)
type(a)
# Out:
# 25
# int

# %% [markdown]
# **31.add two integer 14 and 26 and print the result**

# %%
a=14
b=26
c=a+b
c
# Out:
# 40

# %% [markdown]
# **32. how do you create a float variable with the value 7.5?**

# %%
b=7.5
b
# Out:
# 7.5

# %% [markdown]
# **33.how do create a complex number with a real part 4 and an imaginary part of 3?**

# %%
c=4+3j
c
# Out:
# (4+3j)

# %% [markdown]
# **34.assign a complex number 3+4j to a variable z and print its type .**

# %%
z=3+4j
type(z)
# Out:
# complex

# %% [markdown]
# **35.substract 1+1j from 5+6j and print the result .**

# %%
a=1+1j
b=5+6j
c=b-a
c
# Out:
# (4+5j)

# %% [markdown]
# **36.how do you create a boolean variable that is set to False ?**

# %%
a=0
bool(a)
# Out:
# False

# %% [markdown]
# **37.how do you create a string  variable with value "python"?**

# %%
my_variable ="python"
my_variable
# Out:
# 'python'

# %% [markdown]
# **38.how do you check the data type of a variable x?**

# %%
# we check any data type by using *type()*

x=10
print(type(x))
x='rks'
type(x)
# Out:
# <class 'int'>
# str

# %% [markdown]
# **39.how do you convert the integer10 to a float?**

# %%
x=10
print(type(x))
print(float(x))
# Out:
# <class 'int'>
# 10.0

# %% [markdown]
# **40.how do you convert the float 12.34 to an integer?**

# %%
a=12.34
print(type(a))
int(a)
# Out:
# <class 'float'>
# 12

# %% [markdown]
# **41.how do you convert the string "100" to an integer?**

# %%
b="100"
print(b)
print(type(b))
print(int(b))
# Out:
# 100
# <class 'str'>
# 100

# %% [markdown]
# **42.how do you convert the integer 50 to a strig?**

# %%
a=50
print(type(a))
str(a)
# Out:
# <class 'int'>
# '50'

# %% [markdown]
# **43.how do you find the length of the string language="python"?**

# %%
language="python"
len(language)
# Out:
# 6

# %% [markdown]
# **44.how do you multiply the string "Hi"by 3?**

# %%
z='HI'*3
print(z)
# Out:
# HIHIHI

# %% [markdown]
# **45.how do you convert the string "3.14" to a float?**

# %%
s="3.14"
print(type(s))
float(s)
# Out:
# <class 'str'>
# 3.14

# %% [markdown]
# **46.How do you get the real part of the complex number z=5+6j?**

# %%
z=5+6j
z.real
# Out:
# 5.0

# %% [markdown]
# **47.How do you get the imaginary part of the complex number z=5+6j?**

# %%
z=5+6j
z.imag
# Out:
# 6.0

# %% [markdown]
# **48.how to convert a boolean value True to an integer?**

# %%
a=True
print(type(a))
int(a)
# Out:
# <class 'bool'>
# 1

# %% [markdown]
# **48.how to convert the integer 1 to a boolean?**

# %%
i=1
type(i)
bool(i)
# Out:
# True

# %% [markdown]
# **49.ask the user to input a number and assign it to the variable num.print the value of num.**

# %%
num=input("insert a number")
print(num)
# Out:
# insert a number 5
# 5

# %% [markdown]
# **50.ask the user to input a name and assign it to the variable name.print the value of name.**

# %%
name=input("enter your name")
name
# Out:
# enter your name Ramakant
# 'Ramakant'

# %% [markdown]
# **51.ask the user to input a floating-point number and assign it to the variable price .print the value of price**

# %%
price=input("enter the floting point number")
price
# Out:
# enter the floting point number 56.44
# '56.44'

# %% [markdown]
# **52.ask the user to input a number as a string ,convert it to an integer,and assign it to the variable age,print the value of age.**

# %%
num=str(input("enter the number as a string"))
print(num)
print(type(num))
age=int(num) 
print(age)
type(age)
# Out:
# enter the number as a string 5
# 5
# <class 'str'>
# 5
# int

# %%
values = input("Enter values separated by spaces: ").split()
print("You entered:", values)
# Out:
# Enter values separated by spaces:  6 'adsaf'
# You entered: ['6', "'adsaf'"]

# %% [markdown]
# **53.ask the user to input a number and a word,then assign the number to num (as an integer) and the word to text.print both num and text**

# %%
num,word=input().split()

num ,word
# Out:
#  4 sdkhgk
# ('4', 'sdkhgk')

# %%
num=int(input("enter a number"))
text=str(input("enter a word in text"))
print(num,text)
# Out:
# enter a number 3
# enter a word in text sghdk
# 3 sghdk

# %% [markdown]
# **54.ask the user to input a number,typecast it to a float and assign it to a varaible score.print the value of score and its type**

# %% [markdown]
# num=input("enter a number")
# score=float(num)
# print(score)
# type(score)

# %% [markdown]
# **55.ask the user to input a number,convert it to a string and assign it to a varaible number_str.print the value of number_str and its type**

# %%
num=input("enter a number")
number_str=str(num)
print(number_str)
type(number_str)
# Out:
# enter a number 56
# 56
# str

# %% [markdown]
# **56.take user input for two numbers and print their sum**

# %%
num1=int(input("enter the first number "))
num2=int(input("enter the second number"))
sum=num1+num2
sum
# Out:
# enter the first number  7
# enter the second number 8
# 15

# %% [markdown]
# **57.ask the user for a floating-point number and print its square**

# %%
num=float(input("enter the floating number"))
num=num**2
num
# Out:
# enter the floating number 9
# 81.0

# %% [markdown]
# **58.take input for a complex number and print its real and imaginary parts**

# %%
num=complex(input("enter a complex number"))
print(num.real)
num.imag
# Out:
# enter a complex number 3+4j
# 3.0
# 4.0

# %% [markdown]
# **59.how do you create a string varaible with the value "python"?**

# %%
value="python"
value
# Out:
# 'python'

# %% [markdown]
# **60.assign the string "python" to a variable language and print its length**

# %%
language="python"
print(language)
len(language)
# Out:
# python
# 6

# %% [markdown]
# **61.how do you access the third character of the string language="python"**

# %%
language="python"
language[2]
# Out:
# 't'

# %% [markdown]
# **62..how do you access the third character of the string language="python"**

# %%
language="python"
language[-1]
# Out:
# 'n'

# %% [markdown]
# **63.how do you slice the string language="python" to get "pyt"?**

# %%
language="python"
language[0:3]
# Out:
# 'pyt'

# %% [markdown]
# **64.assign the string "substring" to word and print the last four characters.**

# %%
word="substring"
print(len(word))
print(word[5::])
word[-1:-5:-1]
# Out:
# 9
# ring
# 'gnir'

# %% [markdown]
# **65.how do you slice the string language="python" to get "tho"?**

# %%
language="python"
print(len(language))
language[2:5]
# Out:
# 6
# 'tho'

# %% [markdown]
# **66.assign the string "data science" to text and slice the string to print"data".**

# %%
text='data science'
text[0:4]
# Out:
# 'data'

# %% [markdown]
# **67assign the string "artificial intelligence" to ai and slice the string to print"artificial".**

# %%
ai="artificial intelligence"
a='artificial'
print(len(a))
ai[:10]
# Out:
# 10
# 'artificial'

# %% [markdown]
# **68.assign the string"programming" to term and print the substring"gram".**

# %%
term="programming"
print(len(term))
term[3:7]
# Out:
# 11
# 'gram'

# %% [markdown]
# **69.how do you reverse the string language="python"**

# %%
language="python"
language[::-1]
# Out:
# 'nohtyp'

# %% [markdown]
# **70.assign the string "python programming "to a variable course,delete the variable course.**

# %%
course="python programming "
print(course)
del course
course
# Out:
# python programming
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[152], line 4
#       2 print(course)
#       3 del course
# ----> 4 course
#
# NameError: name 'course' is not defined

# %% [markdown]
# **71.assign the string "OpenAI"to company and convert it to lowercase,then print it.**

# %%
company="OpenAI"
company.lower()
# Out:
# 'openai'

# %% [markdown]
# **72.assign the string "learning"to activity and convert it to uppercase,then print it.**

# %%
activity="learning"
activity.upper()
# Out:
# 'LEARNING'

# %% [markdown]
# **73.assign the string "OpenAI"to company and and remove any leading space,then print the result.**

# %%
company='  OpenAI   '
print(company)
print(company.lstrip())
company.lstrip()
# Out:
#   OpenAI
# OpenAI
# 'OpenAI   '

# %% [markdown]
# **74.assign the string "Data Science"to field and and remove any trailling space,then print the result.**

# %%
field ="   Data Science   "
field.rstrip()
# Out:
# '   Data Science'

# %% [markdown]
# **75.assign the string "python"to text and remove the leading  any trailling space,then print the result.**

# %%
text="   python   "
text.strip()
# Out:
# 'python'

# %% [markdown]
# **76.assign the string "hello" to greeting and capitalize the first letter,then print the result.**

# %%
greeting ="HELLO"
greeting.capitalize()
# Out:
# 'Hello'

# %% [markdown]
# **77.assign the string "hello ,world!" to text and convert it to title case,then print the result**

# %%
text="hello,world!"
text.title()
# Out:
# 'Hello,World!'

# %% [markdown]
# **78.assign the string "banana" to fruit and count the occurrences of "a",then print the result**

# %%
fruit="banana"
fruit.count('a')
# Out:
# 3

# %% [markdown]
# **79.assign the string "python is fun" to sentence and  find the index of "fun",then print the result.**

# %%
sentence="python is fun"
sentence.index("fun")
# Out:
# 10

# %% [markdown]
# **80.assign the string"Alphabet" to text and find the first occurrence of "a"(case -insensitive), then print the result**

# %%
text="Alphabet"
t=text.lower()
print(t)
t.count("a")
# Out:
# alphabet
# 2

# %% [markdown]
# **81.assign the string "This is a test" to sentence and split it into a list of words ,then print the result**

# %%
sentence="this is a test"
sentence.split()
# Out:
# ['this', 'is', 'a', 'test']

# %% [markdown]
# **82.assign the string "join" to word and join it with a hyphen "-" between each letter,then print the result**

# %%
word='Join'
"-".join(word)
# Out:
# 'J-o-i-n'

# %% [markdown]
# **83.how you check if the string "12345" contains only digit?**

# %%
s='12345'
s.isdigit()
# Out:
# True

# %% [markdown]
# **84.assign the string "python3"to language and check if it is alphanumeric,then print the result.**

# %%
language="python3"
language.isalnum()
# Out:
# True

# %% [markdown]
# **85.how do you replace the substring'thon' in the string language='python'with 'ck'.**

# %%
language="python"
language.replace("thon","ck")
# Out:
# 'pyck'

# %%
greeting="hello world!"
greeting.replace("world","python")
# Out:
# 'hello python!'

# %%
s="python"
s.startswith("p")
# Out:
# True

# %%
s="python"

# %%
s="HELLO"
print(s[0])  #FIRST CHARACTER
len(s)
# Out:
# H
# 5

# %%
s[1]
# Out:
# 'E'

# %%
s[-1]         # LAST CHARACTER  S[-1] or s[len(s)-1]
# Out:
# 'O'

# %%
s[-3           #  USING NEGATIVES INDEXING
# Out:
# 'L'

# %%
s[len(s)-1]
# Out:
# 'O'

# %%
s[-6]        # IF WE TRY ACCESS INDEX WITH OUT OF RANGE ,WE WILL GET INDEX ERROR
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 s[-6]
#
# IndexError: string index out of range

# %%
s[5]        # IF WE TRY ACCESS INDEX WITH OUT OF RANGE ,WE WILL GET INDEX ERROR
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 s[5]
#
# IndexError: string index out of range

# %%
s[2.1]             #IF WE TRY TO ACCESS BY USING USE DECIMAL NUMBER ,WE WIL GET ERROR
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 s[2.1]
#
# TypeError: string indices must be integers, not 'float'

# %% [markdown]
# **string slicing**

# %%
s
# Out:
# 'HELLO'

# %%
s[0:4:1]
# Out:
# 'HELL'

# %%
s[0:5:1]
# Out:
# 'HELLO'

# %%
s[1:7:1]
# Out:
# 'ELLO'

# %%
s[1:-1:1]
# Out:
# 'ELL'

# %%
s[-1:-5:-1]
# Out:
# 'OLLE'

# %%
s[-1:-6:-1]
# Out:
# 'OLLEH'

# %%
s[0:4:2]
# Out:
# 'HL'

# %%
s="HELLO"
s
# Out:
# 'HELLO'

# %%
s[4:0:-1]
# Out:
# 'OLLE'

# %%
s[:4:2]     # DEFAULT  STRAT INDEX =0
# Out:
# 'HL'

# %%
s[0::1]    # DEFAULT END INDEX =len(str)
# Out:
# 'HELLO'

# %%
s[0:4:]      #DEFAULT STEP =+1
# Out:
# 'HELL'

# %%
# PRITN THE "HELLO " WORD IN REVERSE ORDER?
s[::-1]
# Out:
# 'OLLEH'

# %% [markdown]
# # PRITN  your *name* IN REVERSE ORDER?

# %%
a="RAMAKANT"
print(a)
# Out:
# RAMAKANT

# %%
a[::-1]
# Out:
# 'TNAKAMAR'

# %%
a[0:7:2]
# Out:
# 'RMKN'

# %%
d="abcdefg"
print(d)
# Out:
# abcdefg

# %%
d[2:5:0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 d[2:5:0]
#
# ValueError: slice step cannot be zero

# %%
text = "abcdefghijk"
slice1 = text[-5:-2:1]
slice1
# Out:
# 'ghi'

# %%
a="abcdefghij"
len(a)
a[::-2]
# Out:
# 'jhfdb'

# %%
a[3:7:2]
# Out:
# 'df'

# %%
q="1234567890"
q[::-3][::-1]
# Out:
# '1470'

# %%
a="abcdefgh"
a[4:2:-1]
# Out:
# 'ed'

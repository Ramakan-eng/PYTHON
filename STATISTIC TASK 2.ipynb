# %%
import pandas as pd

# %%
df=pd.DataFrame({ 'name':['Alice','Bob','Charlie','Davai','Eva','Frank',
                          'Grace','Helen','Lan','jane'],
                 'gender':['F','M','M','M','F','M','F','F','M','F'],
                 'mark':[85,90,78,92,88,75,89,94,70,80],
                 'grade':['A','A','B','A','A','C','A','A','C','B'],
                 'study_hour':[15,18,12,20,16,10,14,22,9,11]})
df
# Out:
#       name gender  mark grade  study_hour
# 0    Alice      F    85     A          15
# 1      Bob      M    90     A          18
# 2  Charlie      M    78     B          12
# 3    Davai      M    92     A          20
# 4      Eva      F    88     A          16
# 5    Frank      M    75     C          10
# 6    Grace      F    89     A          14
# 7    Helen      F    94     A          22
# 8      Lan      M    70     C           9
# 9     jane      F    80     B          11

# %%
df['gender'].value_counts()
# Out:
# gender
# F    5
# M    5
# Name: count, dtype: int64

# %%
df['gender'].value_counts() / len(df['gender'])
# Out:
# gender
# F    0.5
# M    0.5
# Name: count, dtype: float64

# %%
df['gender'].value_counts(normalize = True)
# Out:
# gender
# F    0.5
# M    0.5
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(x=df['gender'])
plt.show()

# %%
sns.histplot(df['mark'],bins=10,stat='probability')
# Out:
# <Axes: xlabel='mark', ylabel='Probability'>

# %%
sns.histplot(df['mark'],bins=10,stat='probability',cumulative = True)
# Out:
# <Axes: xlabel='mark', ylabel='Probability'>

# %%
df['mark'].skew()
# Out:
# -0.5515472798345239

# %%
df['mark'].cov(df['study_hour'])
# Out:
# 32.255555555555546

# %%
sns.kdeplot(df['mark'])
# Out:
# <Axes: xlabel='mark', ylabel='Density'>

# %%
zscore = (45-70)/10
print(zscore)
# Out:
# -2.5

# %%
import scipy.stats as s
s.norm.cdf(-1.1)
# Out:
# 0.13566606094638267

# %%
from scipy import stats
stats.norm.cdf(-1.1)
# Out:
# 0.13566606094638267

# %%
stats.norm.ppf(.99)
# Out:
# 2.3263478740408408

# %%
stats.norm.cdf(2.32)
# Out:
# 0.9898295613312803
